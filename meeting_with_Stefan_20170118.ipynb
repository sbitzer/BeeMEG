# %%
# %matplotlib notebook
import helpers
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# # Behaviour in relation to 5th dot
# ## Single subject

# %%
run analyse_5thdot_behaviour.py 23
# Out:
# Optimization terminated successfully.
#          Current function value: 0.488124
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:             is_correct   No. Observations:                  480
# Model:                          Logit   Df Residuals:                      478
# Method:                           MLE   Df Model:                            1
# Date:                Wed, 18 Jan 2017   Pseudo R-squ.:                  0.1701
# Time:                        14:51:01   Log-Likelihood:                -234.30
# converged:                       True   LL-Null:                       -282.32
#                                         LLR p-value:                 1.124e-22
# ...
#                       coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------
# Intercept           1.0323      0.118      8.754      0.000         0.801     1.263
# ...

# %% [markdown]
# ## All subjects

# %%
run analyse_5thdot_behaviour.py None
# Out:
# Optimization terminated successfully.
#          Current function value: 0.548241
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.483592
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.491392
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564856
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.535678
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.553249
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.569471
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.500921
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.489371
#          Iterations 6
# ...

# %%
subject_info['mlog10_logit_p'] = -np.log10(subject_info.logit_p)
subject_info
# Out:
#          logit_intercept  logit_coef       logit_p  mlog10_logit_p
# subject
# 2               0.914536    0.006980  1.231919e-11       10.909418
# 3               1.070983    0.010871  2.472571e-22       21.606851
# 4               1.047520    0.010439  3.975232e-21       20.400638
# 5               0.793254    0.007089  2.355378e-12       11.627939
# 6               0.836948    0.009000  8.371438e-18       17.077200
# 7               0.821483    0.007737  4.368738e-14       13.359644
# 8               0.700364    0.007711  1.869071e-14       13.728374
# 9               0.991793    0.010232  8.036683e-21       20.094923
# 10              1.139822    0.009418  1.913200e-17       16.718240
# 11              1.040584    0.010137  3.150983e-20       19.501554
# 12              0.640482    0.005242  5.621748e-08        7.250129
# 13              0.755185    0.006193  4.505208e-10        9.346285
# 14              0.661103    0.004553  2.150443e-06        5.667472
# ...

# %%
sns.plt.figure()
sns.distplot(subject_info.mlog10_logit_p, kde=False, rug=True);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Basic regression of 'support correct' on MEG

# %% [markdown]
# Linear regression:
# $$y = \beta \cdot x + \beta_0$$
# with $x$ being support correct.
#
# Using spatio-temporal cluster-level permutation analysis to compute multiple-comparison corrected p-values of $\beta$.
#
# ## p-values of largest cluster in data for all subjects

# %%
subs = helpers.find_available_subjects(megdatadir='data/meg_final_data')
with np.load('data/inf_results/clusres_5thdot_meg_201701171125.npz') as res:
    max_cluster_p = pd.Series(res['max_cluster_p'], name='p of largest cluster',
                              index=pd.Index(subs, name='subject'))

sns.plt.figure()
sns.distplot(max_cluster_p, kde=False, rug=True);
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# # Regression of sign of support correct

# %%
subs = helpers.find_available_subjects(megdatadir='data/meg_final_data')
with np.load('data/inf_results/clusres_5thdot_meg_201701171447.npz') as res:
    max_cluster_p_sign = pd.Series(res['max_cluster_p'], name='p of largest cluster',
                                   index=pd.Index(subs, name='subject'))

sns.plt.figure()
sns.distplot(max_cluster_p_sign, kde=False, rug=True);
# Out:
# <img src="data:image/png;base64,...">

# %%
max_cluster_p_sign.sort_values()
# Out:
# subject
# 33    0.000976
# 34    0.000976
# 17    0.007805
# 16    0.011707
# 18    0.012683
# 24    0.013659
# 7     0.023415
# 23    0.028293
# 35    0.042927
# 13    0.047805
# 29    0.073171
# 32    0.077073
# 6     0.081951
# 8     0.087805
# 4     0.127805
# 21    0.159024
# 10    0.170732
# 28    0.189268
# 26    0.240000
# 9     0.347317
# 27    0.418537
# 36    0.423415
# 31    0.468293
# 22    0.539512
# 2     0.594146
# 15    0.615610
# 5     0.708293
# 11    0.728780
# 25    0.735610
# 20    0.763902
# 37    0.793171
# 3     0.897561
# 12    0.925854
# 19    0.934634
# Name: p of largest cluster, dtype: float64

# %% [markdown]
# # Correlation between p-values of behaviour and MEG

# %%
subject_info['mlog10_clus_p'] = -np.log10(max_cluster_p_sign)
sns.jointplot('mlog10_logit_p', 'mlog10_clus_p', data=subject_info);
# Out:
# <img src="data:image/png;base64,...">
